# %% [markdown]
# # Binomial, Poisson and Gaussian distributions
#
# ### Authors:
# - Christian Michelsen (Niels Bohr Institute)
# - Troels C. Petersen (Niels Bohr Institute)
#
# ### Date:
# - 07-11-2018 (latest update)
#
# ***
#
# Python notebook for illustrating the Binomial, Poisson and Gaussian distributions and how they transform into each other (well, into the Gaussian).
#
# Reference:
# -   Barlow, chapter 3
#
# ***

# %%
import numpy as np                                     # Matlab like syntax for linear algebra and functions
import matplotlib.pyplot as plt                        # Plots and figures like you know them from Matlab
import seaborn as sns                                  # Make the plots nicer to look at
from iminuit import Minuit                             # The actual fitting tool, better than scipy's
from probfit import BinnedLH, Chi2Regression, Extended # Helper tool for fitting
import sys                                             # Modules to see files and folders in directories

from scipy import stats
from scipy.stats import binom, poisson, norm

# %% [markdown]
# We set up the parameters for the program:

# %%
# Set parameters:
r = np.random                       # Random generator
r.seed(42)                          # Fixed order of random numbers

save_plots = False
verbose = True
N_verbose = 10

N_experiments = 1000

# %% [markdown]
# ----------------------------------------------------------------------------------
# Initial figures:
# ----------------------------------------------------------------------------------

# %%
def func_binomial_pmf(x, n, p):
    return binom.pmf(x, n, p)

# %%
def func_gaussian_pdf(x, mu, sigma) :
    return norm.pdf(x, mu, sigma)

# %%
n, p = 10, 0.2

# %%
xaxis = np.linspace(-0.5, 10.5, 1000)
yaxis_binom = func_binomial_pmf(np.floor(xaxis+0.5), n, p) # note the floor command here
yaxis_gauss = func_gaussian_pdf(xaxis, n*p, np.sqrt(n*p*(1-p)))

# %%
fig0, ax0 = plt.subplots(figsize=(14, 8))
ax0.plot(xaxis, yaxis_binom, '-', label=f'Binomial with n={n:2d} and p={p:.3f}')
ax0.plot(xaxis, yaxis_gauss, '-', label=f'Gaussian with mu={n*p:.2f} and sigma={np.sqrt(n*p*(1-p)):.3f}')
ax0.set(xlim=(-0.5, 10.5), 
        title='Probability for Binomial and Gaussian', 
        xlabel='x', 
        ylabel='Probability',
       )
ax0.legend(loc='upper right');

# %% [markdown]
# ## Loop over process:
#
# Define process, i.e. number of trials and probability of success:

# %%
N_trials = 2000
p_success = 1/60
Lambda = N_trials * p_success     # This is the mean and also how the Poisson parameter is defined!

# %% [markdown]
# Loop pver the process:

# %%
all_n_success = np.zeros(N_experiments)

# Run the experiments, and fill the histogram from above:
for iexp in range(N_experiments): 
    
    # Simulating process defined:
    n_success = 0
    for i in range(N_trials): 
        x = r.uniform()
        if (x < p_success): 
            n_success += 1

    # Record result:
    if (verbose and iexp < N_verbose): 
        print(f"n_success: {n_success:4d}")
        
    # Save Result
    all_n_success[iexp] = n_success
# Out:
# n_success:   27
# n_success:   39
# n_success:   30
# n_success:   29
# n_success:   37
# n_success:   38
# n_success:   34
# n_success:   30
# n_success:   28
# n_success:   31

# %% [markdown]
# ## Plot result:
#
# Define a histogram with the "data" (note and think about the binning!):

# %%
counts, bin_edges = np.histogram(all_n_success, bins=N_trials+1, range=(-0.5, N_trials+0.5))
bin_centers = (bin_edges[1:] + bin_edges[:-1])/2
s_counts = np.sqrt(counts)

# %%
x = bin_centers[counts>0]
y = counts[counts>0]
sy = s_counts[counts>0]

# %%
fig, ax = plt.subplots(figsize=(14, 8))
ax.errorbar(x, y, yerr=sy, xerr=0.5, label='Distribution of nSuccebs', fmt='.k',  ecolor='k', elinewidth=1, capsize=1, capthick=1)
ax.set(xlim=(-0.5, 60), xlabel='Number of successes', ylabel='Frequency');

# %% [markdown]
# ## Binomial:
#
# First define the function:

# %%
def func_binomial(x, N, n, p):
    return N * binom.pmf(x, n, p)

# %% [markdown]
# Then fit it with a $\chi^2$-fit:

# %%
chi2_bin = Chi2Regression(func_binomial, x, y, sy)
minuit_bin = Minuit(chi2_bin, pedantic=False, N=N_experiments, n=N_trials, p=p_success) #   
minuit_bin.migrad();  # perform the actual fitb
# Out:
# <hr>
# <table>
#     <tr>
#         <td title="Minimum value of function">FCN = 35.83870612996794</td>
#         <td title="Total number of call to FCN so far">TOTAL NCALL = 1174</td>
#         <td title="Number of call in last migrad">NCALLS = 1174</td>
#     </tr>
#     <tr>
#         <td title="Estimated distance to minimum">EDM = 0.00010958860191381727</td>
#         <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#         <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#         UP = 1.0</td>
#     </tr>
# </table>
# <table>
#     <tr>
#         <td align="center" title="Validity of the migrad call">Valid</td>
#         <td align="center" title="Validity of parameters">Valid Param</td>
#         <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#         <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
# ...

# %% [markdown]
# And plot it on the figure:

# %%
xaxis = np.linspace(-0.5, 60-0.5, 1000)
yaxis = func_binomial(np.floor(xaxis+0.5), *minuit_bin.args)
ax.plot(xaxis, yaxis, '-', label='Binomial distribution')
fig

# %% [markdown]
# ## Poisson:

# %%
def func_poisson(x, N, mu) :
    return N * poisson.pmf(x, mu)

# %%
chi2_poisson = Chi2Regression(func_poisson, x, y, sy)
minuit_poisson = Minuit(chi2_poisson, pedantic=False, N=N_experiments, mu=Lambda) #   
minuit_poisson.migrad();  # perform the actual fit
# Out:
# <hr>
# <table>
#     <tr>
#         <td title="Minimum value of function">FCN = 38.52390491886158</td>
#         <td title="Total number of call to FCN so far">TOTAL NCALL = 29</td>
#         <td title="Number of call in last migrad">NCALLS = 29</td>
#     </tr>
#     <tr>
#         <td title="Estimated distance to minimum">EDM = 3.2084106123513565e-07</td>
#         <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#         <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#         UP = 1.0</td>
#     </tr>
# </table>
# <table>
#     <tr>
#         <td align="center" title="Validity of the migrad call">Valid</td>
#         <td align="center" title="Validity of parameters">Valid Param</td>
#         <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#         <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
# ...

# %%
# Note that the np.floor function takes the integer/rounded (towards zero) value of numbers.
yaxis = func_poisson(np.floor(xaxis+0.5), *minuit_poisson.args)
ax.plot(xaxis, yaxis, '-', label='Poisson distribution')
fig

# %% [markdown]
# ## Gaussian:

# %%
def func_gaussian(x, N, mu, sigma) :
    return N * norm.pdf(x, mu, sigma)

# %%
chi2_gaussian = Chi2Regression(func_gaussian, x, y, sy)
minuit_gaussian = Minuit(chi2_gaussian, pedantic=False, N=N_experiments, mu=Lambda, sigma=np.sqrt(Lambda)) #   
minuit_gaussian.migrad();  # perform the actual fit
# Out:
# <hr>
# <table>
#     <tr>
#         <td title="Minimum value of function">FCN = 41.69942697046005</td>
#         <td title="Total number of call to FCN so far">TOTAL NCALL = 52</td>
#         <td title="Number of call in last migrad">NCALLS = 52</td>
#     </tr>
#     <tr>
#         <td title="Estimated distance to minimum">EDM = 1.0287865897493588e-05</td>
#         <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#         <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#         UP = 1.0</td>
#     </tr>
# </table>
# <table>
#     <tr>
#         <td align="center" title="Validity of the migrad call">Valid</td>
#         <td align="center" title="Validity of parameters">Valid Param</td>
#         <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#         <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
# ...

# %%
yaxis = func_gaussian(xaxis, *minuit_gaussian.args)
ax.plot(xaxis, yaxis, '-', label='Gaussian distribution')

ax.legend()
fig.tight_layout()

fig

# %% [markdown]
# And save the figure:

# %%
if save_plots: 
    fig.savefig("BinomialPoissonGaussian.pdf")

# %% [markdown]
# ## Calculation of $\chi^2$-values:
#
# Here comes your calculation of ChiSquare values! I suggest you use Pearson's $\chi^2$, and require `N_obs` and/or `N_experiments` > e.g. 0.1. Remember with your choice to ensure, that there is no division by zero.

# %%
N_bins = len(x)                # Just to know how many bins to loop over
chi2_bino = 0.0
N_dof = 0

# %%
for N_obs, xi in zip(y, x):
    if (N_obs > 0) :
        N_exp_bino = func_binomial(xi, *minuit_bin.args)

# %%
print("\nJust a test printout, change to match your own results! \n")
print(f"Binomial:   chi2 = {9999:5.2f}   N_dof = {9999:2d}   Prob = {9999:6.4f}")
# Out:
# Just a test printout, change to match your own results!
#
# Binomial:   chi2 = 9999.00   N_dof = 9999   Prob = 9999.0000

# %% [markdown]
# ***
#
# Make sure you understand what process yields a Binomial, a Poisson and a Gaussian
# distribution.
#
# The program repeats an experiment, where one performs N trials, each with p chance
# of success, and then considers the distribution of successes.
#
# # Questions:
#
# 1. Plot a Binomial ($N=27$, $p=1/3$), Poisson ($\lambda = 9$), and Gaussian ($\mu=9$, $\sigma=3$). Which distribution has the longest tail towards high values? And which one has the longest tail the other way? Possibly also do a logarithmic plot.
#
# 2. Using `N_experiments=1000`, `N_trials=10` and `p_success=1/6`, calculate "by hand" (i.e. using a loop) the ChiSquare between the data and each of the three distributions. Since you are not fitting anything, what is the number of degrees of freedom? Do they give a reasonable $\chi^2$-probability Retry with `N_trials=100` and `p_success=1/60`. Does the degree of fit improve for any of the three? Retry again with `N_trials=1000` and `p_success=1/60`. Again, does the quality of the fit improve further for any of the three?
#
# 3. In the above case with `N_trials=100` and `p_success=1/60`, calculate the mean and the width of the distribution. Do they have the relation, that you would expect from a Poisson distribution? Try it for other values where the Poisson describes the data well, and check if the Poisson relation between mean and width holds.
#
# ## Advanced questions:
#
# 4. Using `N_experiments=1000`, `N_trials=1000` and `p_success=1/60`, is the skewness consistent with zero (as the Gaussian should have)? Does that contradict the conclusion from above?
